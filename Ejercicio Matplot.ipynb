# %% [markdown]
# 1. Crear una vble x que tenga 10 valores equidistantes entre 0 y 20
# 2. Crear una vble y que contenga los valores de la funcion x al cuadrado +5
# 3. crear un gráfico de color rojo, con ancho de 5v vy estilo de puntos

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,20,10)

# %%
y = (x**2)+5

# %%
x
# Out:
# array([ 0.        ,  2.22222222,  4.44444444,  6.66666667,  8.88888889,
#        11.11111111, 13.33333333, 15.55555556, 17.77777778, 20.        ])

# %%
y
# Out:
# array([  5.        ,   9.9382716 ,  24.75308642,  49.44444444,
#         84.01234568, 128.45679012, 182.77777778, 246.97530864,
#        321.04938272, 405.        ])

# %%
figura = plt.figure()
grafico= figura.add_axes([0.1,0.1,0.9,0.9])
grafico.plot(x,y,'green', linestyle=':', linewidth=5)
